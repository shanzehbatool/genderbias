# %%
# !mkdir debiaswe_tutorial
# %cd debiaswe_tutorial
# !git clone https://github.com/tolga-b/debiaswe.git
# Out:
# /content/debiaswe_tutorial
# Cloning into 'debiaswe'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 95 (delta 0), reused 0 (delta 0), pack-reused 91
# Unpacking objects: 100% (95/95), done.

# %%
pip install scipy

# %%
pip install scikit-learn

# %%
from __future__ import print_function, division
# %matplotlib inline
from matplotlib import pyplot as plt
import json
import random
import numpy as np

import debiaswe.debiaswe as dwe
import debiaswe.debiaswe.we as we
from debiaswe.debiaswe.we import WordEmbedding
from debiaswe.debiaswe.data import load_professions

# %%
# load google news word2vec
E = WordEmbedding('/content/w2v_gnews_small.txt')

# load professions
professions = load_professions()
profession_words = [p[0] for p in professions]
# Out:
# *** Reading data from /content/w2v_gnews_small.txt
# (26423, 300)
# 26423 words of dimension 300 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine
# Loaded professions
# Format:
# word,
# definitional female -1.0 -> definitional male 1.0
# stereotypical female -1.0 -> stereotypical male 1.0

# %%
import os

file_path = "/content/Rockstar.pdf"

# writing data in variable
text = os.popen("pdftotext {}".format(file_path)).read()

# %%
for page in text:
    print(page)

# %%
#NEW BEGINNINGS

# %%
pip install numpy

# %%
pip install scipy

# %%
pip install gensim

# %%
pip install nltk

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from gensim.models import Word2Vec

# %%
# !pip install pdfplumber -q
import pdfplumber
# Out:
#      |████████████████████████████████| 46 kB 3.4 MB/s
#      |████████████████████████████████| 5.6 MB 46.5 MB/s
#      |████████████████████████████████| 4.3 MB 68.4 MB/s
#      |████████████████████████████████| 139 kB 58.4 MB/s
#      |████████████████████████████████| 3.6 MB 55.7 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
import pdfplumber

# %%
page = pdf.pages[0]

# %%
text = page.extract_text()

# %%
print(text)

# %%
page = pdf.pages[265]

# %%
text = page.extract_text()
text

# %%
pdf = pdfplumber.open('/content/Last.pdf')

data = []

# List of every page's text.
# The index will correspond to the page number.
pdf_text = [0]  # zero is a placehoder to make page 1 = index 1
#pdf_reader = PyPDF2.PdfFileReader(f)
for page in pdf.pages:
    
    #page = pdf_reader.getPage(p)
    #print(page)
    
    #pdf_text.append(page.extract_text())
    #print(pdf_text[page])

    print(page.extract_text())

    #corpus_text = 'n'.join(rev[:1000]['Text'])

    # iterate through each sentence in the file
    for i in sent_tokenize(str(page.extract_text())):
        #print(i)
        temp = []
    # tokenize the sentence into words
        for j in word_tokenize(i):
            temp.append(j.lower())
        data.append(temp)
# Out:
# A large crowd gathers outside the Verona Arena in Italy to watch the performance of rockstar Jordan.
# Despite being mobbed, he storms onto the stage in a fit of rage and starts strumming his guitar.
# A flashback reveals the story of Jordan, whose real name is Janardhan Jakhar a.k.a. JJ, a Jat boy from
# Delhi. He is studying at Hindu College and dreams of being a rockstar like Jim Morrison, for which he is
# often laughed at by his friends. Khatana, the canteen owner, tells JJ that one thing common among all
# artists is a life-altering heartbreak. JJ jokingly tells himself that since that hasn't happened yet, he won't
# be able to reach his idol's status. He watches the dance performance of Heer Kaul, a beautiful girl from
# St. Stephen's College during a contest, and overhears that she is the "perfect-heartbreaking-machine."
# Remembering Khatana's words, he decides to propose to her but suffers humiliation, which he sees as
# ...

# %%
data
# Out:
# [['a',
#   'large',
#   'crowd',
#   'gathers',
#   'outside',
#   'the',
#   'verona',
#   'arena',
#   'in',
#   'italy',
#   'to',
#   'watch',
#   'the',
#   'performance',
#   'of',
#   'rockstar',
#   'jordan',
#   '.'],
#  ['despite',
#   'being',
#   'mobbed',
#   ',',
#   'he',
#   'storms',
#   'onto',
#   'the',
#   'stage',
#   'in',
#   'a',
#   'fit',
#   'of',
#   'rage',
#   'and',
#   'starts',
#   'strumming',
#   'his',
#   'guitar',
#   '.'],
#  ['a',
#   'flashback',
#   'reveals',
#   'the',
#   'story',
#   'of',
#   'jordan',
#   ',',
#   'whose',
#   'real',
#   'name',
#   'is',
#   'janardhan',
#   'jakhar',
#   'a.k.a',
#   '.'],
#  ['jj', ',', 'a', 'jat', 'boy', 'from', 'delhi', '.'],
#  ['he',
#   'is',
#   'studying',
#   'at',
#   'hindu',
#   'college',
#   'and',
#   'dreams',
#   'of',
#   'being',
#   'a',
#   'rockstar',
#   'like',
#   'jim',
#   'morrison',
#   ',',
#   'for',
#   'which',
#   'he',
#   'is',
#   'often',
#   'laughed',
# ...

# %%
len(data)
# Out:
# 229

# %%
modelwe = gensim.models.Word2Vec(data, min_count = 1,size = 100, window = 5, sg=0)

# %%
len(modelwe.wv.vocab)
# Out:
# 1245

# %%
from collections import OrderedDict

# %%
#my_dict = OrderedDict()

# %%
'''my_dict = dict({})
for idx, key in enumerate(we1.wv.vocab):
    my_dict[key] = we1.wv[key]
    print(my_dict[key])'''
# Out:
# Streaming output truncated to the last 5000 lines.
#   0.01403673  0.00602     0.03846963 -0.04670329  0.01517972  0.00935222
#  -0.00546765  0.0032413   0.00021355  0.03466718 -0.00768522  0.00736349
#  -0.01575296 -0.02857153  0.00086636  0.00543196 -0.0054362  -0.02219963
#  -0.02437895 -0.02860962 -0.00447967 -0.0235887  -0.01917594 -0.00193144
#   0.00474817  0.01406449 -0.02921688  0.03918283 -0.01376645  0.01920515
#  -0.01851116 -0.01953741  0.05870904 -0.00655526  0.02280833  0.03355832
#  -0.00183018 -0.02966946 -0.01042554 -0.01062572]
# [-0.07008146 -0.06203718  0.1372461   0.07994119  0.06261361 -0.09651197
#  -0.13316174 -0.03445652  0.04250799 -0.10164528 -0.01367524 -0.00572262
#   0.0543379   0.11786978  0.00383776  0.05233333 -0.00818246 -0.06279686
#  -0.0321194  -0.03834285  0.01266779  0.00595612  0.09285579  0.01593584
#  -0.06825494 -0.07996304  0.07288158 -0.00692564  0.08432861  0.00799016
# ...

# %%
#len(my_dict)
# Out:
# 4748

# %%
pdf = pdfplumber.open('/content/Pink.pdf')

data1 = []

# List of every page's text.
# The index will correspond to the page number.
pdf_text = [0]  # zero is a placehoder to make page 1 = index 1
#pdf_reader = PyPDF2.PdfFileReader(f)
for page in pdf.pages:
    
    #page = pdf_reader.getPage(p)
    #print(page)
    
    #pdf_text.append(page.extract_text())
    #print(pdf_text[page])

    print(page.extract_text())

    #corpus_text = 'n'.join(rev[:1000]['Text'])

    # iterate through each sentence in the file
    for i in sent_tokenize(str(page.extract_text())):
        #print(i)
        temp = []
    # tokenize the sentence into words
        for j in word_tokenize(i):
            temp.append(j.lower())
        data1.append(temp)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 35
#
# Warn  kar  saktey  hain  -  uske
# alaava  bhi  hum  -  nahi  uske
# alava  kya  kareingey  -  matlab
# kuchh  bhi  action  lengey  toh
# phir  inpe  bhi  toh  charge
# lagega...  assault  kiya  hai
# inhoney  ladke  ko  -  aap  sure
# hain  ki  aap  complaint  karna
# chahti  hain  kyunki  phir
# detailed inquiry hogi aur unki
# bhi counter complaint aa sakti
# hai - unka FIR bhi register ho
# sakta  hai  kyunki  hua  toh  sab
# nashe mein hi na sabse!
# Minal doesn't know what to say. She nods.
# MINAL
# Sir  lekin  abhi  jo  voh  log
# phone pe dhamki de rahe hein..
# SHAUKEEN
# Thook  gali  ya  dhamki  ka  kya
# hai  -  it  is  nothing  -  Thank
# God  uss  din  koi  badi  ghatna
# nahi hui - aap safe ho! But ab
# mujhe thoda gussa bhi aa raha
# hai  aappe...  Aise  ladkun  ke
# saath  jaati  hai  koi  achhi
# ladki -  kamrey mein aap khud
# gaye  -  hansey  -  joking  ki  -
# hain... ab kartey aap sab ho -
# ...

# %%
len(data1)
# Out:
# 2712

# %%
we1.build_vocab(data1, update=True)
#we1.train(total_examples=we1.corpus_count,epochs=we1.epochs)

# %%
len(we1.wv.vocab)
# Out:
# 7417

# %%
my_dict = OrderedDict()

# %%
my_dict = dict({})
for idx, key in enumerate(modelwe.wv.vocab):
    my_dict[key] = modelwe.wv[key]
    print(my_dict[key])
# Out:
# Streaming output truncated to the last 5000 lines.
#   1.7740589e-03 -3.4337535e-03  1.5183486e-03  4.2584320e-03
#   1.4632582e-03 -4.4856560e-03  5.0336984e-04 -1.6921827e-03
#  -1.3109550e-03 -2.6446648e-03 -2.6584298e-03  2.7449527e-03
#   4.8574671e-04 -1.5809161e-03  4.7710845e-03  2.3097615e-03
#  -5.3077643e-03  2.6429893e-04 -3.5246690e-03  2.3553977e-03
#  -7.8686001e-04 -3.5006765e-03  3.0964441e-03  2.8121092e-03
#   3.6596751e-03 -2.6028729e-03  2.8910302e-03  8.9752569e-04
#  -2.7942122e-03  3.1821569e-03 -5.2514402e-05  4.6078951e-04]
# [-2.7048008e-03  2.6697910e-03 -1.3613226e-03 -2.2091479e-03
#  -8.3510723e-04  3.5883270e-03  2.7758915e-03 -2.7243479e-04
#  -1.4138435e-03 -2.7912464e-03 -8.4486464e-04 -4.2579114e-03
#   1.5469335e-03  4.0482725e-03 -1.7260365e-03  3.3065677e-04
#  -9.1309531e-04  7.7746669e-04 -9.7104919e-04 -1.9320562e-03
#   3.1488499e-04 -4.6823570e-03 -4.8033362e-03  3.2090324e-03
#   2.0893796e-03  1.3848746e-03  3.8705638e-03 -2.9890952e-03
# ...

# %%
len(my_dict)
# Out:
# 1245

# %%
for word in my_dict.keys():
    print(word)
# Out:
# a
# large
# crowd
# gathers
# outside
# the
# verona
# arena
# in
# italy
# to
# watch
# performance
# of
# rockstar
# jordan
# .
# despite
# being
# mobbed
# ,
# he
# storms
# onto
# stage
# fit
# rage
# and
# starts
# strumming
# his
# guitar
# flashback
# reveals
# story
# whose
# real
# name
# is
# janardhan
# jakhar
# a.k.a
# jj
# jat
# boy
# from
# delhi
# studying
# at
# hindu
# college
# dreams
# like
# jim
# morrison
# for
# which
# often
# laughed
# by
# friends
# khatana
# canteen
# owner
# tells
# that
# one
# thing
# common
# among
# all
# artists
# life-altering
# heartbreak
# jokingly
# himself
# since
# has
# n't
# happened
# yet
# wo
# be
# able
# reach
# idol
# 's
# status
# watches
# dance
# heer
# kaul
# beautiful
# girl
# st.
# stephen
# during
# contest
# overhears
# she
# ``
# perfect-heartbreaking-machine
# ''
# remembering
# words
# decides
# propose
# her
# but
# suffers
# humiliation
# sees
# as
# perfect
# method
# enduring
# needed
# stardom
# over
# ...

# %%
modelwe['marriage']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 2.3049170e-03,  4.4379504e-03, -1.5357181e-03,  2.5359367e-03,
#         3.7676156e-03,  6.7038520e-04,  4.3621967e-03,  6.4110995e-04,
#         3.5777732e-03, -3.2687776e-03, -5.0386214e-03,  2.8132477e-03,
#        -1.1145725e-03,  5.8892889e-05, -3.6373790e-03,  4.0265592e-03,
#         2.0440551e-04,  2.5806371e-03,  1.6468080e-03,  1.3976319e-03,
#        -4.5601483e-03, -6.5279775e-04,  4.7163060e-03,  4.8790881e-03,
#        -3.7640368e-03,  2.4628800e-03,  1.3274399e-03,  2.1898933e-03,
#         4.4191214e-03, -7.1572600e-04,  3.6165793e-03, -2.8863109e-03,
#        -2.3952650e-03,  2.4675864e-03, -8.9651148e-04, -2.5293068e-03,
#         1.3458104e-03,  5.5913268e-05,  1.2459230e-03, -5.4792017e-03,
# ...

# %%
for word in my_dict.keys() :
    weights = str(modelwe[word])
    file1 = open("/content/save1.txt", "a")  # append mode
    file1.write(word + " " + weights + "\n")
    print(word)
    print(weights)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Streaming output truncated to the last 5000 lines.
# nine-year-old
# [ 2.8043045e-03 -1.9009556e-03  1.1253783e-03 -4.1792970e-03
#   2.8174010e-03  3.9042854e-03 -1.2387370e-03 -2.6986466e-03
#  -4.0776473e-03  2.2551348e-03 -2.0960285e-03  3.9096763e-03
#  -3.8119841e-03 -2.8170743e-03  2.4773779e-03  1.7579620e-03
#   3.0865872e-03 -1.3592792e-03  4.0561273e-03  1.1625320e-03
#  -4.1065835e-03 -3.3721549e-03 -4.5952732e-03 -1.1844378e-03
#   1.3711247e-04  2.3831388e-03  1.7928074e-03  4.5486931e-03
#   9.2204486e-04  4.6764784e-03  4.8851618e-03 -1.0016320e-03
#  -9.2331425e-04 -1.3920076e-03 -1.9979011e-03 -4.3209717e-03
#   2.0951210e-04  2.2564237e-03  3.8879702e-03  1.2641496e-03
#  -1.9937423e-03  1.0473136e-03  1.5425042e-03  2.0951270e-03
# ...

# %%
# !mkdir debiaswe_tutorial
# %cd debiaswe_tutorial
# !git clone https://github.com/tolga-b/debiaswe.git
# Out:
# /content/debiaswe_tutorial
# Cloning into 'debiaswe'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 95 (delta 0), reused 0 (delta 0), pack-reused 91
# Unpacking objects: 100% (95/95), done.

# %%
pip install scipy

# %%
pip install scikit-learn

# %%
from __future__ import print_function, division
# %matplotlib inline
from matplotlib import pyplot as plt
import json
import random
import numpy as np

import debiaswe.debiaswe as dwe
import debiaswe.debiaswe.we as we
from debiaswe.debiaswe.we import WordEmbedding
from debiaswe.debiaswe.data import load_professions

# %%
# load google news word2vec
E = WordEmbedding('/content/trying.txt')

# load professions
#professions = load_professions()
#profession_words = [p[0] for p in professions]
# Out:
# *** Reading data from /content/trying.txt
# (1250, 100)
# 1250 words of dimension 100 : a, large, crowd, gathers, ..., female, male, Mary, John
# 1250 words of dimension 100 : a, large, crowd, gathers, ..., female, male, Mary, John

# %%
# gender direction
v_gender = E.diff('she', 'he')

# %%
# analogies gender
a_gender = E.best_analogies_dist_thresh(v_gender)

for (a,b,c) in a_gender:
    print(a+"-"+b)
# Out:
# Computing neighbors
# Mean: 11.4912
# Median: 6.0
# she-he
# officer-left
# based-murders
# days-get
# injured-depressed
# them-about
# confides-end
# prostitute-stay
# take-good
# within-becomes
# reaching-travel
# shootout-fights
# snatches-mistaking
# also-granddaughters
# through-refuses
# this-who
# migrant-aimlessly
# number-kaul
# answers-jordan
# wo-jai
# life-)
# as-heer
# i-beat
# most-hilaal
# kill-ritual
# different-watch
# nature-now
# rings-funeral
# have-liking
# a-off
# criminal-industrialist
# sleep-kabir
# various-revived
# impression-:
# prayer-concerts
# bargains-ghazala
# rebuffed-invade
# together-both
# beautiful-narayan
# --gets
# younger-hug
# morrison-leave
# someone-spiritually
# unaware-reuniting
# pieces-militia
# joins-manager
# farewell-day
# own-suicide
# .-while
# stranger-resides
# argument-separatist
# begin-learns
# out-away
# whose-wealthy
# diagnosed-pieces
# details-janardhan
# threatens-chatting
# pro-separatist-they
# turn-blackmail
# ...

# %%
#E.most_similar(positive=["she",'career'],negative=["he"],topn=5)

# %%
we1.most_similar(positive=['man'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('they', 0.9983803033828735),
#  ('room', 0.9983416199684143),
#  ('street', 0.9983323812484741),
#  ('security', 0.9983112812042236),
#  ('by', 0.9983028173446655),
#  ('there', 0.9982895851135254),
#  ('dhingra', 0.9982864856719971),
#  ('has', 0.9982700347900391),
#  ('se…', 0.9982668161392212),
#  ('playing', 0.9982652068138123)]

# %%
modelwe.most_similar(positive=['woman'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('one', 0.39535218477249146),
#  ('becomes', 0.3649732768535614),
#  ('closing', 0.35011807084083557),
#  ('chagrin', 0.3456078767776489),
#  ('rimjhim', 0.33282580971717834),
#  ('sees', 0.328802227973938),
#  ('but', 0.3242003321647644),
#  ('information', 0.3202051520347595),
#  ('her', 0.31438004970550537),
#  (',', 0.3142160475254059)]

# %%
we1.most_similar(positive=['girl'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('has', 0.9995747804641724),
#  ('by', 0.9995706081390381),
#  ('their', 0.9995453357696533),
#  ('music', 0.9995421171188354),
#  ('we', 0.9995415210723877),
#  ('some', 0.9995406866073608),
#  ('ke', 0.9995325803756714),
#  ('–', 0.9995198249816895),
#  ('hain', 0.9995138049125671),
#  ('into', 0.999512255191803)]

# %%
we1.most_similar(positive=['boy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('delhi', 0.9988192915916443),
#  ('meri', 0.9987950921058655),
#  ('gaya', 0.9987548589706421),
#  ('some', 0.9987519979476929),
#  ('bahot', 0.9987487196922302),
#  ('le', 0.998747706413269),
#  ('kaha', 0.9987413287162781),
#  ('ek', 0.9987395405769348),
#  ('ko', 0.9987341165542603),
#  ('–', 0.998733639717102)]

# %%
we1.most_similar(positive=['she'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('he', 0.999925971031189),
#  ('as', 0.99991375207901),
#  ('up', 0.9998962879180908),
#  ('is', 0.9998933672904968),
#  ('the', 0.9998902082443237),
#  ('jordan', 0.99988853931427),
#  ('her', 0.9998874068260193),
#  ('.', 0.9998859763145447),
#  ('out', 0.9998774528503418),
#  ('in', 0.9998759031295776)]

# %%
we1.most_similar(positive=['he'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('she', 0.999925971031189),
#  ('her', 0.9999186992645264),
#  ('the', 0.9999109506607056),
#  ('as', 0.9999011754989624),
#  ('is', 0.9999009370803833),
#  ('up', 0.9998971819877625),
#  ('.', 0.9998968839645386),
#  ('him', 0.9998968243598938),
#  ('out', 0.9998869895935059),
#  ('towards', 0.9998586177825928)]

# %%
we1.most_similar(positive=["woman",'doctor'],negative=["man"],topn=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('2am', 0.3293946087360382),
#  ('toda', 0.31483370065689087),
#  ('nashey', 0.2917591333389282),
#  ('maana', 0.2903537154197693),
#  ('uttrey', 0.28967970609664917)]

# %%
we1.most_similar(positive=["she",'career'],negative=["he"],topn=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('hote', 0.9872474670410156),
#  ('haath', 0.9870744943618774),
#  ('pyaar', 0.9869958162307739),
#  ('liye…', 0.9869481921195984),
#  ('bhaiya', 0.9869390726089478)]

# %%
from debiaswe.debiaswe.debias import debias

# %%
# Lets load some gender related word lists to help us with debiasing
with open('/content/debiaswe_tutorial/debiaswe/data/definitional_pairs.json', "r") as f:
    defs = json.load(f)
print("definitional", defs)

with open('/content/debiaswe_tutorial/debiaswe/data/equalize_pairs.json', "r") as f:
    equalize_pairs = json.load(f)

with open('/content/debiaswe_tutorial/debiaswe/data/gender_specific_seed.json', "r") as f:
    gender_specific_words = json.load(f)
print("gender specific", len(gender_specific_words), gender_specific_words[:10])
# Out:
# definitional [['woman', 'man'], ['girl', 'boy'], ['she', 'he'], ['mother', 'father'], ['daughter', 'son'], ['gal', 'guy'], ['female', 'male'], ['her', 'his'], ['herself', 'himself'], ['Mary', 'John']]
# gender specific 218 ['actress', 'actresses', 'aunt', 'aunts', 'bachelor', 'ballerina', 'barbershop', 'baritone', 'beard', 'beards']

# %%
debias(E, gender_specific_words, defs, equalize_pairs)
# Out:
# 1250 words of dimension 100 : a, large, crowd, gathers, ..., female, male, Mary, John
# ...

# %%
E.more_words_like_these('him', topn=5, max_freq=100000)
# Out:
# ['have', 'i', 'music', 'after', 'janardan']

# %%
E.more_words_like_these('she', topn=5, max_freq=100000)
# Out:
# ['venue', 'camera', 'makes', 'who', 'college']

# %%
# analogies gender
a_gender_debiased = E.best_analogies_dist_thresh(v_gender)

for (a,b,c) in a_gender_debiased:
    print(a+"-"+b)
# Out:
# Computing neighbors
# Mean: 10.7616
# Median: 7.0
# officer-left
# falcon-us
# based-murders
# days-get
# pro-separatist-wealthy
# them-about
# confides-end
# reaching-travel
# prostitute-stay
# within-becomes
# shootout-fights
# snatches-mistaking
# also-granddaughters
# through-refuses
# this-who
# number-kaul
# migrant-aimlessly
# buys-race
# answers-jordan
# injured-translated
# even-arena
# wo-jai
# i-beat
# right-sign
# morally-orientation
# as-heer
# kill-ritual
# words-strumming
# different-watch
# have-liking
# impression-:
# there-encounters
# rings-funeral
# criminal-industrialist
# nature-now
# a-off
# rebuffed-invade
# bargains-ghazala
# stranger-resides
# jim-want
# beautiful-narayan
# prayer-concerts
# whose-way
# younger-hug
# .-while
# various-revived
# sleep-kabir
# own-suicide
# of-good
# argument-separatist
# together-both
# joins-manager
# morrison-leave
# bhatt-cause
# unaware-reuniting
# suggests-refusing
# --gets
# someone-spiritually
# begin-learns
# ...
